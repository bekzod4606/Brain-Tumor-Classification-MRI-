# %% [markdown]
# ### **Importing Libraries**

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB0, EfficientNetB7, MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings

# %%
for dirname, _, filenames in os.walk('/content/drive/MyDrive/dataset'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(34).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(127).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(22).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(20).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(26).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(118).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(24).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(13).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(15).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(102).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(32).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(29).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(14).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(121).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(123).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(113).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(100).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(30).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(3).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(124).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(33).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(107).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(23).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(11).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(28).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(120).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(19).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(112).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(27).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(17).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(35).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(18).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(126).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(125).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(109).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(25).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(1).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(106).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(31).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(16).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(21).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(2).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(12).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(10).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(92).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(45).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(36).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(97).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(70).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(9).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(71).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(4).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(38).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(61).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(86).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(68).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(72).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(90).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(89).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(5).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(50).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(94).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(44).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(96).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(46).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(79).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(95).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(51).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(67).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(99).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(8).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(54).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(81).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(76).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(58).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(41).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(6).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(52).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(93).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(47).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image.jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(80).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(82).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(7).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(75).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(60).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(85).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(39).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(59).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(37).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(63).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(55).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(88).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(91).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(66).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(69).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(98).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(65).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(64).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(83).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(49).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(77).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(74).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(43).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(56).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(53).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(78).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(42).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(87).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(84).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(57).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(48).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(40).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(73).jpg
# /content/drive/MyDrive/dataset/Testing/meningioma_tumor/image(62).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(77).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(51).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(15).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(89).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(13).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(67).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(20).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(60).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(97).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(46).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(94).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(10).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(88).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(41).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(47).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(18).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(66).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(54).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(34).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(65).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(91).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(73).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(85).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(78).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(81).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(76).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(19).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(31).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(79).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(63).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(55).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(11).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(48).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(57).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(3).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(1).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(38).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(87).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(98).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(61).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(30).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(42).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(92).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(82).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(22).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(96).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image.jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(5).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(52).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(28).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(2).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(8).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(27).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(53).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(56).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(90).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(68).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(23).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(21).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(44).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(7).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(37).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(49).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(69).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(95).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(64).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(35).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(70).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(45).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(36).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(6).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(93).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(43).jpg
# /content/drive/MyDrive/dataset/Testing/pituitary_tumor/image(86).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(11).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(15).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(13).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(100).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(16).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(10).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(19).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(17).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(14).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(2).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(18).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(92).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(78).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(93).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(50).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(27).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(21).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(33).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(39).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(89).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(41).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(46).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(97).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(66).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(82).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(87).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(67).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(60).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(99).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(62).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(8).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(48).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(85).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(30).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(84).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(79).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(75).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(51).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(44).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(26).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(61).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(37).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(52).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(98).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image.jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(5).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(29).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(6).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(55).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(58).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(22).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(25).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(42).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(34).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(7).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(83).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(43).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(38).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(31).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(76).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(94).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(72).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(77).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(68).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(63).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(91).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(57).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(20).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(74).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(36).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(4).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(71).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(81).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(56).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(40).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(35).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(95).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(23).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(9).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(86).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(88).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(69).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(80).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(54).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(3).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(59).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(47).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(70).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(45).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(49).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(1).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(12).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(24).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(28).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(32).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(53).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(65).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(64).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(73).jpg
# /content/drive/MyDrive/dataset/Testing/glioma_tumor/image(90).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(59).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(4).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(25).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(12).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(52).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(91).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(82).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(15).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(97).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(99).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(40).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(49).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(85).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(14).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(88).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(11).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(1).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(61).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(35).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(26).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(51).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(33).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(78).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(27).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(32).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(18).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(80).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(38).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(34).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(23).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(60).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(84).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(96).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(48).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(95).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(39).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(64).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(43).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(37).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(56).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(31).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(74).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(2).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(29).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image.jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(65).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(20).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(41).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(46).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(103).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(90).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(93).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(73).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(71).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(16).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(19).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(68).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(100).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(101).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(13).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(54).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(5).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(30).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(83).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(58).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(76).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(57).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(47).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(98).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(102).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(81).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(22).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(10).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(77).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(3).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(63).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(28).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(89).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(75).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(7).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(8).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(42).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(72).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(24).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(45).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(69).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(9).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(66).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(94).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(87).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(62).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(50).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(70).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(21).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(17).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(67).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(92).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(6).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(44).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(55).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(53).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(79).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(86).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(104).jpg
# /content/drive/MyDrive/dataset/Testing/no_tumor/image(36).jpg
# /content/drive/MyDrive/dataset/Training/.DS_Store
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (331).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (383).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (197).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (313).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (352).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (340).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (199).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (151).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (167).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (221).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (307).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (198).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (433).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (261).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (29).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (474).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (468).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (133).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (13).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (25).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (266).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (33).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (401).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (296).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (200).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (418).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (249) (1).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (177).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (374).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (244).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (302).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (484).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (154).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (263).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (169).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (195).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (253).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (250).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (379).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (158).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (462).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (225).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (326).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (481).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (176).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (469).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (101).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (361).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (132).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (222).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (457).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (138).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (371).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (37).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (421).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (170).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (150).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (207).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (311).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (336).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (17).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (31).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (102).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (373).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (152).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (426).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (403).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (125).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (493).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (256).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (144).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (385).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (441).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (406).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (230).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (41).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (470).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (204).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (265).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (186).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (111).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (308).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (4).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (463).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (217).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (327).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (289).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (381).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (139).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (390).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (270).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (420).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (39).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (320).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (323).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (405).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (127).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (439).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (328).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (10).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (122).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (246).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (193).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (330).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (466).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (389).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (147).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (414).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (161).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (100).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (121).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (135).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (454).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (182).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (243).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (475) (1).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (2).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (202).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (241).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (393).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (448).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (188).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (412).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (280).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (116).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (229).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (343).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (47).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (317).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (189).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (267).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (417).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (300).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (377).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (368).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (423).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (376).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (400).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (451).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (409).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (107).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (119).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (274).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (442).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (477).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (375).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (236).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (228).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (15).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (455) (1).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (483).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (164).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (166).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (131).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (279).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (240).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (277).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (160) (1).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (23).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (20).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (338).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (325).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (103).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (349).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (424).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (220).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (435).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (486).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (329).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (398).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (28).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (44).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (272).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (341).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (419).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (315).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (40).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (190).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (194).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (227).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (314).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (450).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (128).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (35).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (239).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (440).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (410).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (171).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (322).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (378).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (104).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (160).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (354).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (369).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (183).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (351).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (215).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (32).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (304).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (129).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (452).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (436).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (213).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (14).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (431).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (206).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (471).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (34).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (372).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (288).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (140) (1).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (112).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (359).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (303).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (286).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (382).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (476).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (106).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (292).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (142).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (333).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (438).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (363).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (278).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (392).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (156).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (284).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (49).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (126).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (24).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (301).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (233).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (273).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (218).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (260).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (299).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (472).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (298).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (45).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (465).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (26).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (413).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (407).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (173).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (384).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (181).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (344).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (464).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (143).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (259).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (123).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (427).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (257).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (211).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (489).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (391).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (490).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (345).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (324).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (157).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (297).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (309).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (18).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (460).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (285).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (36).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (455).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (114).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (337).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (395).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (22).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (201).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (251).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (120).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (146).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (334).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (482).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (321).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (430).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (479).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (196).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (16).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (137).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (428).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (281).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (12).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (485).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (434).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (402) (1).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (245).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (258).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (306).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (473).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (115).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (456).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (362).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (480).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (247).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (402).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (118).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (339).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (224).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (42).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (141).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (168).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (305).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (386).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (335).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (179).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (223).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (287).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (238).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (235).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (353).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (3).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (255).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (159).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (355).jpg
# /content/drive/MyDrive/dataset/Training/pituitary_tumor/p (347).jpg
# ...
# /content/drive/MyDrive/dataset/Training/no_tumor/image(222).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (15).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(55).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(7).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(301).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(129).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(107).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (57).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(21).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(293).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (27).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (26).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(182).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(118).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(178).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(49).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(48).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(22).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(204).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(257).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (44).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (35).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(14).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(274).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(85).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(3).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(4).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(310).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(106).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(81).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(92).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(155).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(96).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (8).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(262).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(236).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(266).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(258).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(72).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(276).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (36).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (12).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(171).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(24).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(181).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(108).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (32).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (46).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(199).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (54).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(270).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(114).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(57).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(321).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(294).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(134).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(221).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (20).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(13).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(241).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(29).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(75).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(1).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(23).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(219).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(318).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(56).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(137).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(68).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(123).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(177).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(235).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(242).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/2.jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(102).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(249).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (48).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(323).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(115).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(220).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(128).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(30).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(120).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(104).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(297).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (60).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(167).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(61).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image.jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (41).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(232).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(172).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(208).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (11).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(145).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(147).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(103).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (34).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (61).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (28).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(160).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (59).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(195).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(146).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(217).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (13).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(261).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(142).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(216).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(269).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (21).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (7).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(153).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(231).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(47).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/6.jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (31).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(311).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(307).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(194).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(286).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(12).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(138).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (14).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(299).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(124).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(77).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(281).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(298).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(282).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(132).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(267).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(251).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(99).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(237).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(125).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (23).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(126).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (22).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (18).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(113).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(302).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (40).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(296).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/4.jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(64).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (5).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (52).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(215).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(226).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(20).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (63).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(253).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(32).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(305).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(40).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (4).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(148).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(93).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(229).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (64).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(259).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(272).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (24).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(50).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(320).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(271).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(152).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(150).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(112).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(243).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(227).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(284).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (29).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(95).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (56).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/1.jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(87).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(168).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(327).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(53).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(246).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(69).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(260).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (9).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(131).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(82).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(225).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(247).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(308).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(175).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(183).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(280).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(317).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(191).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(139).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(98).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (43).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(316).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (58).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(143).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(144).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(16).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(149).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(17).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(200).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(252).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(201).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(206).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(300).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(319).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(67).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(154).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(176).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(184).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(60).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(11).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (30).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(211).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(127).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(304).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(6).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(8).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(110).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(71).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(111).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(62).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(41).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(250).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(288).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(166).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(156).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(278).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(90).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(292).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(275).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(287).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(79).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(73).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(58).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image (25).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(157).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(84).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(162).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(218).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(101).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/7.jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(285).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(277).jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/8.jpg
# /content/drive/MyDrive/dataset/Training/no_tumor/image(303).jpg

# %% [markdown]
# ### **Colors**

# %%
colors_dark = ["#1F1F1F", "#313131", '#636363', '#AEAEAE', '#DADADA']
colors_red = ["#331313", "#582626", '#9E1717', '#D35151', '#E9B4B4']
colors_green = ['#01411C','#4B6F44','#4F7942','#74C365','#D0F0C0']

sns.palplot(colors_dark)
sns.palplot(colors_green)
sns.palplot(colors_red)

# %% [markdown]
# ### **Data Preparation**

# %%
labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']

# %% [markdown]
# We start off by appending all the images from the directories into a Python list and then converting them into numpy arrays after resizing it.

# %%
X_train = []
y_train = []
image_size = 150
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/dataset','Training',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)

for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/dataset','Testing',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)

X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 826/826 [00:20<00:00, 39.51it/s]
# 100%|██████████| 405/405 [00:10<00:00, 37.37it/s]
# 100%|██████████| 863/863 [00:26<00:00, 32.16it/s]
# 100%|██████████| 837/837 [00:19<00:00, 42.82it/s]
# 100%|██████████| 100/100 [00:02<00:00, 47.35it/s]
# 100%|██████████| 105/105 [00:01<00:00, 56.13it/s]
# 100%|██████████| 115/115 [00:04<00:00, 24.10it/s]
# 100%|██████████| 74/74 [00:30<00:00,  2.45it/s]

# %%
k=0
fig, ax = plt.subplots(1,4,figsize=(20,20))
fig.text(s='Sample Image From Each Label',size=18,fontweight='bold',
             fontname='monospace',color=colors_dark[1],y=0.62,x=0.4,alpha=0.8)
for i in labels:
    j=0
    while True :
        if y_train[j]==i:
            ax[k].imshow(X_train[j])
            ax[k].set_title(y_train[j])
            ax[k].axis('off')
            k+=1
            break
        j+=1

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=101)

# %%
X_train.shape
# Out:
# (3325, 150, 150, 3)

# %% [markdown]
# Dividing the dataset into Training and Testing sets.

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)

# %% [markdown]
# Performing **One Hot Encoding** on the labels after converting it into numerical values:

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %% [markdown]
# ### **Transfer** **Learning**

# %% [markdown]
# Deep convolutional neural network models may take days or even weeks to train on very large datasets.
#
# A way to short-cut this process is to re-use the model weights from pre-trained models that were developed for standard computer vision benchmark datasets, such as the ImageNet image recognition tasks. Top performing models can be downloaded and used directly, or integrated into a new model for your own computer vision problems.
#
# In this notebook, I'll be using the **EfficientNetB0** model which will use the weights from the **ImageNet** dataset.
#
# The include_top parameter is set to False so that the network doesn't include the top layer/ output layer from the pre-built model which allows us to add our own output layer depending upon our use case!

# %%
effnet = EfficientNetB7(weights='imagenet',include_top=False,input_shape=(image_size,image_size,3))
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258076736/258076736 [==============================] - 2s 0us/step

# %%
effnet.summary()
# Out:
# Model: "efficientnetb7"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 150, 150, 3)          0         ['input_1[0][0]']
#
#  normalization (Normalizati  (None, 150, 150, 3)          7         ['rescaling[0][0]']
#  on)
#
#  rescaling_1 (Rescaling)     (None, 150, 150, 3)          0         ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 151, 151, 3)          0         ['rescaling_1[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 75, 75, 64)           1728      ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 75, 75, 64)           256       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 75, 75, 64)           0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 75, 75, 64)           576       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 75, 75, 64)           256       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 75, 75, 64)           0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 64)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 64)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 16)             1040      ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 64)             1088      ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 75, 75, 64)           0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 75, 75, 32)           2048      ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 75, 75, 32)           128       ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1b_dwconv (DepthwiseC  (None, 75, 75, 32)           288       ['block1a_project_bn[0][0]']
#  onv2D)
#
#  block1b_bn (BatchNormaliza  (None, 75, 75, 32)           128       ['block1b_dwconv[0][0]']
#  tion)
#
#  block1b_activation (Activa  (None, 75, 75, 32)           0         ['block1b_bn[0][0]']
#  tion)
#
#  block1b_se_squeeze (Global  (None, 32)                   0         ['block1b_activation[0][0]']
#  AveragePooling2D)
#
#  block1b_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1b_se_squeeze[0][0]']
#  e)
#
#  block1b_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multipl  (None, 75, 75, 32)           0         ['block1b_activation[0][0]',
#  y)                                                                  'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv  (None, 75, 75, 32)           1024      ['block1b_se_excite[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 75, 75, 32)           128       ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_drop (Dropout)      (None, 75, 75, 32)           0         ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)           (None, 75, 75, 32)           0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseC  (None, 75, 75, 32)           288       ['block1b_add[0][0]']
#  onv2D)
#
#  block1c_bn (BatchNormaliza  (None, 75, 75, 32)           128       ['block1c_dwconv[0][0]']
#  tion)
#
#  block1c_activation (Activa  (None, 75, 75, 32)           0         ['block1c_bn[0][0]']
#  tion)
#
#  block1c_se_squeeze (Global  (None, 32)                   0         ['block1c_activation[0][0]']
#  AveragePooling2D)
#
#  block1c_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1c_se_squeeze[0][0]']
#  e)
#
#  block1c_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multipl  (None, 75, 75, 32)           0         ['block1c_activation[0][0]',
#  y)                                                                  'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv  (None, 75, 75, 32)           1024      ['block1c_se_excite[0][0]']
#  2D)
#
#  block1c_project_bn (BatchN  (None, 75, 75, 32)           128       ['block1c_project_conv[0][0]']
#  ormalization)
#
#  block1c_drop (Dropout)      (None, 75, 75, 32)           0         ['block1c_project_bn[0][0]']
#
#  block1c_add (Add)           (None, 75, 75, 32)           0         ['block1c_drop[0][0]',
#                                                                      'block1b_add[0][0]']
#
#  block1d_dwconv (DepthwiseC  (None, 75, 75, 32)           288       ['block1c_add[0][0]']
#  onv2D)
#
#  block1d_bn (BatchNormaliza  (None, 75, 75, 32)           128       ['block1d_dwconv[0][0]']
#  tion)
#
#  block1d_activation (Activa  (None, 75, 75, 32)           0         ['block1d_bn[0][0]']
#  tion)
#
#  block1d_se_squeeze (Global  (None, 32)                   0         ['block1d_activation[0][0]']
#  AveragePooling2D)
#
#  block1d_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1d_se_squeeze[0][0]']
#  e)
#
#  block1d_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1d_se_reshape[0][0]']
#
#  block1d_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1d_se_reduce[0][0]']
#
#  block1d_se_excite (Multipl  (None, 75, 75, 32)           0         ['block1d_activation[0][0]',
#  y)                                                                  'block1d_se_expand[0][0]']
#
#  block1d_project_conv (Conv  (None, 75, 75, 32)           1024      ['block1d_se_excite[0][0]']
#  2D)
#
#  block1d_project_bn (BatchN  (None, 75, 75, 32)           128       ['block1d_project_conv[0][0]']
#  ormalization)
#
#  block1d_drop (Dropout)      (None, 75, 75, 32)           0         ['block1d_project_bn[0][0]']
#
#  block1d_add (Add)           (None, 75, 75, 32)           0         ['block1d_drop[0][0]',
#                                                                      'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 75, 75, 192)          6144      ['block1d_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 75, 75, 192)          768       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 75, 75, 192)          0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv_pad (ZeroPa  (None, 77, 77, 192)          0         ['block2a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block2a_dwconv (DepthwiseC  (None, 38, 38, 192)          1728      ['block2a_dwconv_pad[0][0]']
#  onv2D)
#
#  block2a_bn (BatchNormaliza  (None, 38, 38, 192)          768       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 38, 38, 192)          0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 192)                  0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 38, 38, 192)          0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 38, 38, 48)           9216      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 38, 38, 288)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 38, 38, 288)          0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 288)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 38, 38, 48)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 38, 38, 48)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 38, 38, 288)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2c_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2c_dwconv[0][0]']
#  tion)
#
#  block2c_activation (Activa  (None, 38, 38, 288)          0         ['block2c_bn[0][0]']
#  tion)
#
#  block2c_se_squeeze (Global  (None, 288)                  0         ['block2c_activation[0][0]']
#  AveragePooling2D)
#
#  block2c_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2c_se_squeeze[0][0]']
#  e)
#
#  block2c_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2c_activation[0][0]',
#  y)                                                                  'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2c_se_excite[0][0]']
#  2D)
#
#  block2c_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 38, 38, 48)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 38, 38, 48)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2c_add[0][0]']
#  D)
#
#  block2d_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2d_expand_conv[0][0]']
#  rmalization)
#
#  block2d_expand_activation   (None, 38, 38, 288)          0         ['block2d_expand_bn[0][0]']
#  (Activation)
#
#  block2d_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2d_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2d_dwconv[0][0]']
#  tion)
#
#  block2d_activation (Activa  (None, 38, 38, 288)          0         ['block2d_bn[0][0]']
#  tion)
#
#  block2d_se_squeeze (Global  (None, 288)                  0         ['block2d_activation[0][0]']
#  AveragePooling2D)
#
#  block2d_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2d_se_squeeze[0][0]']
#  e)
#
#  block2d_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2d_activation[0][0]',
#  y)                                                                  'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2d_se_excite[0][0]']
#  2D)
#
#  block2d_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2d_project_conv[0][0]']
#  ormalization)
#
#  block2d_drop (Dropout)      (None, 38, 38, 48)           0         ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)           (None, 38, 38, 48)           0         ['block2d_drop[0][0]',
#                                                                      'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2d_add[0][0]']
#  D)
#
#  block2e_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2e_expand_conv[0][0]']
#  rmalization)
#
#  block2e_expand_activation   (None, 38, 38, 288)          0         ['block2e_expand_bn[0][0]']
#  (Activation)
#
#  block2e_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2e_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2e_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2e_dwconv[0][0]']
#  tion)
#
#  block2e_activation (Activa  (None, 38, 38, 288)          0         ['block2e_bn[0][0]']
#  tion)
#
#  block2e_se_squeeze (Global  (None, 288)                  0         ['block2e_activation[0][0]']
#  AveragePooling2D)
#
#  block2e_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2e_se_squeeze[0][0]']
#  e)
#
#  block2e_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2e_activation[0][0]',
#  y)                                                                  'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2e_se_excite[0][0]']
#  2D)
#
#  block2e_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2e_project_conv[0][0]']
#  ormalization)
#
#  block2e_drop (Dropout)      (None, 38, 38, 48)           0         ['block2e_project_bn[0][0]']
#
#  block2e_add (Add)           (None, 38, 38, 48)           0         ['block2e_drop[0][0]',
#                                                                      'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2e_add[0][0]']
#  D)
#
#  block2f_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2f_expand_conv[0][0]']
#  rmalization)
#
#  block2f_expand_activation   (None, 38, 38, 288)          0         ['block2f_expand_bn[0][0]']
#  (Activation)
#
#  block2f_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2f_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2f_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2f_dwconv[0][0]']
#  tion)
#
#  block2f_activation (Activa  (None, 38, 38, 288)          0         ['block2f_bn[0][0]']
#  tion)
#
#  block2f_se_squeeze (Global  (None, 288)                  0         ['block2f_activation[0][0]']
#  AveragePooling2D)
#
#  block2f_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2f_se_squeeze[0][0]']
#  e)
#
#  block2f_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2f_se_reshape[0][0]']
#
#  block2f_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2f_se_reduce[0][0]']
#
#  block2f_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2f_activation[0][0]',
#  y)                                                                  'block2f_se_expand[0][0]']
#
#  block2f_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2f_se_excite[0][0]']
#  2D)
#
#  block2f_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2f_project_conv[0][0]']
#  ormalization)
#
#  block2f_drop (Dropout)      (None, 38, 38, 48)           0         ['block2f_project_bn[0][0]']
#
#  block2f_add (Add)           (None, 38, 38, 48)           0         ['block2f_drop[0][0]',
#                                                                      'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2f_add[0][0]']
#  D)
#
#  block2g_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2g_expand_conv[0][0]']
#  rmalization)
#
#  block2g_expand_activation   (None, 38, 38, 288)          0         ['block2g_expand_bn[0][0]']
#  (Activation)
#
#  block2g_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2g_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2g_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2g_dwconv[0][0]']
#  tion)
#
#  block2g_activation (Activa  (None, 38, 38, 288)          0         ['block2g_bn[0][0]']
#  tion)
#
#  block2g_se_squeeze (Global  (None, 288)                  0         ['block2g_activation[0][0]']
#  AveragePooling2D)
#
#  block2g_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2g_se_squeeze[0][0]']
#  e)
#
#  block2g_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2g_se_reshape[0][0]']
#
#  block2g_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2g_se_reduce[0][0]']
#
#  block2g_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2g_activation[0][0]',
#  y)                                                                  'block2g_se_expand[0][0]']
#
#  block2g_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2g_se_excite[0][0]']
#  2D)
#
#  block2g_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2g_project_conv[0][0]']
#  ormalization)
#
#  block2g_drop (Dropout)      (None, 38, 38, 48)           0         ['block2g_project_bn[0][0]']
#
#  block2g_add (Add)           (None, 38, 38, 48)           0         ['block2g_drop[0][0]',
#                                                                      'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2g_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 38, 38, 288)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv_pad (ZeroPa  (None, 41, 41, 288)          0         ['block3a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block3a_dwconv (DepthwiseC  (None, 19, 19, 288)          7200      ['block3a_dwconv_pad[0][0]']
#  onv2D)
#
#  block3a_bn (BatchNormaliza  (None, 19, 19, 288)          1152      ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 19, 19, 288)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 288)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 19, 19, 288)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 19, 19, 80)           23040     ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 19, 19, 80)           320       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 19, 19, 480)          38400     ['block3a_project_bn[0][0]']
#  D)
# ...
#  tion)
#
#  block7a_activation (Activa  (None, 5, 5, 2304)           0         ['block7a_bn[0][0]']
#  tion)
#
#  block7a_se_squeeze (Global  (None, 2304)                 0         ['block7a_activation[0][0]']
#  AveragePooling2D)
#
#  block7a_se_reshape (Reshap  (None, 1, 1, 2304)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 96)             221280    ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 2304)           223488    ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, 5, 5, 2304)           0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, 5, 5, 640)            1474560   ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, 5, 5, 640)            2560      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  block7b_expand_conv (Conv2  (None, 5, 5, 3840)           2457600   ['block7a_project_bn[0][0]']
#  D)
#
#  block7b_expand_bn (BatchNo  (None, 5, 5, 3840)           15360     ['block7b_expand_conv[0][0]']
#  rmalization)
#
#  block7b_expand_activation   (None, 5, 5, 3840)           0         ['block7b_expand_bn[0][0]']
#  (Activation)
#
#  block7b_dwconv (DepthwiseC  (None, 5, 5, 3840)           34560     ['block7b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7b_bn (BatchNormaliza  (None, 5, 5, 3840)           15360     ['block7b_dwconv[0][0]']
#  tion)
#
#  block7b_activation (Activa  (None, 5, 5, 3840)           0         ['block7b_bn[0][0]']
#  tion)
#
#  block7b_se_squeeze (Global  (None, 3840)                 0         ['block7b_activation[0][0]']
#  AveragePooling2D)
#
#  block7b_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7b_se_squeeze[0][0]']
#  e)
#
#  block7b_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multipl  (None, 5, 5, 3840)           0         ['block7b_activation[0][0]',
#  y)                                                                  'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv  (None, 5, 5, 640)            2457600   ['block7b_se_excite[0][0]']
#  2D)
#
#  block7b_project_bn (BatchN  (None, 5, 5, 640)            2560      ['block7b_project_conv[0][0]']
#  ormalization)
#
#  block7b_drop (Dropout)      (None, 5, 5, 640)            0         ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)           (None, 5, 5, 640)            0         ['block7b_drop[0][0]',
#                                                                      'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2  (None, 5, 5, 3840)           2457600   ['block7b_add[0][0]']
#  D)
#
#  block7c_expand_bn (BatchNo  (None, 5, 5, 3840)           15360     ['block7c_expand_conv[0][0]']
#  rmalization)
#
#  block7c_expand_activation   (None, 5, 5, 3840)           0         ['block7c_expand_bn[0][0]']
#  (Activation)
#
#  block7c_dwconv (DepthwiseC  (None, 5, 5, 3840)           34560     ['block7c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7c_bn (BatchNormaliza  (None, 5, 5, 3840)           15360     ['block7c_dwconv[0][0]']
#  tion)
#
#  block7c_activation (Activa  (None, 5, 5, 3840)           0         ['block7c_bn[0][0]']
#  tion)
#
#  block7c_se_squeeze (Global  (None, 3840)                 0         ['block7c_activation[0][0]']
#  AveragePooling2D)
#
#  block7c_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7c_se_squeeze[0][0]']
#  e)
#
#  block7c_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multipl  (None, 5, 5, 3840)           0         ['block7c_activation[0][0]',
#  y)                                                                  'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv  (None, 5, 5, 640)            2457600   ['block7c_se_excite[0][0]']
#  2D)
#
#  block7c_project_bn (BatchN  (None, 5, 5, 640)            2560      ['block7c_project_conv[0][0]']
#  ormalization)
#
#  block7c_drop (Dropout)      (None, 5, 5, 640)            0         ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)           (None, 5, 5, 640)            0         ['block7c_drop[0][0]',
#                                                                      'block7b_add[0][0]']
#
#  block7d_expand_conv (Conv2  (None, 5, 5, 3840)           2457600   ['block7c_add[0][0]']
#  D)
#
#  block7d_expand_bn (BatchNo  (None, 5, 5, 3840)           15360     ['block7d_expand_conv[0][0]']
#  rmalization)
#
#  block7d_expand_activation   (None, 5, 5, 3840)           0         ['block7d_expand_bn[0][0]']
#  (Activation)
#
#  block7d_dwconv (DepthwiseC  (None, 5, 5, 3840)           34560     ['block7d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7d_bn (BatchNormaliza  (None, 5, 5, 3840)           15360     ['block7d_dwconv[0][0]']
#  tion)
#
#  block7d_activation (Activa  (None, 5, 5, 3840)           0         ['block7d_bn[0][0]']
#  tion)
#
#  block7d_se_squeeze (Global  (None, 3840)                 0         ['block7d_activation[0][0]']
#  AveragePooling2D)
#
#  block7d_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7d_se_squeeze[0][0]']
#  e)
#
#  block7d_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7d_se_reshape[0][0]']
#
#  block7d_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7d_se_reduce[0][0]']
#
#  block7d_se_excite (Multipl  (None, 5, 5, 3840)           0         ['block7d_activation[0][0]',
#  y)                                                                  'block7d_se_expand[0][0]']
#
#  block7d_project_conv (Conv  (None, 5, 5, 640)            2457600   ['block7d_se_excite[0][0]']
#  2D)
#
#  block7d_project_bn (BatchN  (None, 5, 5, 640)            2560      ['block7d_project_conv[0][0]']
#  ormalization)
#
#  block7d_drop (Dropout)      (None, 5, 5, 640)            0         ['block7d_project_bn[0][0]']
#
#  block7d_add (Add)           (None, 5, 5, 640)            0         ['block7d_drop[0][0]',
#                                                                      'block7c_add[0][0]']
#
#  top_conv (Conv2D)           (None, 5, 5, 2560)           1638400   ['block7d_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 5, 5, 2560)           10240     ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 5, 5, 2560)           0         ['top_bn[0][0]']
#  )
#
# ==================================================================================================
# Total params: 64097687 (244.51 MB)
# Trainable params: 63786960 (243.33 MB)
# Non-trainable params: 310727 (1.19 MB)
# __________________________________________________________________________________________________

# %%
effnet.trainable = False
effnet.summary()
# Out:
# Model: "efficientnetb7"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 150, 150, 3)          0         ['input_1[0][0]']
#
#  normalization (Normalizati  (None, 150, 150, 3)          7         ['rescaling[0][0]']
#  on)
#
#  rescaling_1 (Rescaling)     (None, 150, 150, 3)          0         ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 151, 151, 3)          0         ['rescaling_1[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 75, 75, 64)           1728      ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 75, 75, 64)           256       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 75, 75, 64)           0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 75, 75, 64)           576       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 75, 75, 64)           256       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 75, 75, 64)           0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 64)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 64)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 16)             1040      ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 64)             1088      ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 75, 75, 64)           0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 75, 75, 32)           2048      ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 75, 75, 32)           128       ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1b_dwconv (DepthwiseC  (None, 75, 75, 32)           288       ['block1a_project_bn[0][0]']
#  onv2D)
#
#  block1b_bn (BatchNormaliza  (None, 75, 75, 32)           128       ['block1b_dwconv[0][0]']
#  tion)
#
#  block1b_activation (Activa  (None, 75, 75, 32)           0         ['block1b_bn[0][0]']
#  tion)
#
#  block1b_se_squeeze (Global  (None, 32)                   0         ['block1b_activation[0][0]']
#  AveragePooling2D)
#
#  block1b_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1b_se_squeeze[0][0]']
#  e)
#
#  block1b_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multipl  (None, 75, 75, 32)           0         ['block1b_activation[0][0]',
#  y)                                                                  'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv  (None, 75, 75, 32)           1024      ['block1b_se_excite[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 75, 75, 32)           128       ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_drop (Dropout)      (None, 75, 75, 32)           0         ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)           (None, 75, 75, 32)           0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseC  (None, 75, 75, 32)           288       ['block1b_add[0][0]']
#  onv2D)
#
#  block1c_bn (BatchNormaliza  (None, 75, 75, 32)           128       ['block1c_dwconv[0][0]']
#  tion)
#
#  block1c_activation (Activa  (None, 75, 75, 32)           0         ['block1c_bn[0][0]']
#  tion)
#
#  block1c_se_squeeze (Global  (None, 32)                   0         ['block1c_activation[0][0]']
#  AveragePooling2D)
#
#  block1c_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1c_se_squeeze[0][0]']
#  e)
#
#  block1c_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multipl  (None, 75, 75, 32)           0         ['block1c_activation[0][0]',
#  y)                                                                  'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv  (None, 75, 75, 32)           1024      ['block1c_se_excite[0][0]']
#  2D)
#
#  block1c_project_bn (BatchN  (None, 75, 75, 32)           128       ['block1c_project_conv[0][0]']
#  ormalization)
#
#  block1c_drop (Dropout)      (None, 75, 75, 32)           0         ['block1c_project_bn[0][0]']
#
#  block1c_add (Add)           (None, 75, 75, 32)           0         ['block1c_drop[0][0]',
#                                                                      'block1b_add[0][0]']
#
#  block1d_dwconv (DepthwiseC  (None, 75, 75, 32)           288       ['block1c_add[0][0]']
#  onv2D)
#
#  block1d_bn (BatchNormaliza  (None, 75, 75, 32)           128       ['block1d_dwconv[0][0]']
#  tion)
#
#  block1d_activation (Activa  (None, 75, 75, 32)           0         ['block1d_bn[0][0]']
#  tion)
#
#  block1d_se_squeeze (Global  (None, 32)                   0         ['block1d_activation[0][0]']
#  AveragePooling2D)
#
#  block1d_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1d_se_squeeze[0][0]']
#  e)
#
#  block1d_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1d_se_reshape[0][0]']
#
#  block1d_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1d_se_reduce[0][0]']
#
#  block1d_se_excite (Multipl  (None, 75, 75, 32)           0         ['block1d_activation[0][0]',
#  y)                                                                  'block1d_se_expand[0][0]']
#
#  block1d_project_conv (Conv  (None, 75, 75, 32)           1024      ['block1d_se_excite[0][0]']
#  2D)
#
#  block1d_project_bn (BatchN  (None, 75, 75, 32)           128       ['block1d_project_conv[0][0]']
#  ormalization)
#
#  block1d_drop (Dropout)      (None, 75, 75, 32)           0         ['block1d_project_bn[0][0]']
#
#  block1d_add (Add)           (None, 75, 75, 32)           0         ['block1d_drop[0][0]',
#                                                                      'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 75, 75, 192)          6144      ['block1d_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 75, 75, 192)          768       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 75, 75, 192)          0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv_pad (ZeroPa  (None, 77, 77, 192)          0         ['block2a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block2a_dwconv (DepthwiseC  (None, 38, 38, 192)          1728      ['block2a_dwconv_pad[0][0]']
#  onv2D)
#
#  block2a_bn (BatchNormaliza  (None, 38, 38, 192)          768       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 38, 38, 192)          0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 192)                  0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 38, 38, 192)          0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 38, 38, 48)           9216      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 38, 38, 288)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 38, 38, 288)          0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 288)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 38, 38, 48)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 38, 38, 48)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 38, 38, 288)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2c_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2c_dwconv[0][0]']
#  tion)
#
#  block2c_activation (Activa  (None, 38, 38, 288)          0         ['block2c_bn[0][0]']
#  tion)
#
#  block2c_se_squeeze (Global  (None, 288)                  0         ['block2c_activation[0][0]']
#  AveragePooling2D)
#
#  block2c_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2c_se_squeeze[0][0]']
#  e)
#
#  block2c_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2c_activation[0][0]',
#  y)                                                                  'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2c_se_excite[0][0]']
#  2D)
#
#  block2c_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 38, 38, 48)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 38, 38, 48)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2c_add[0][0]']
#  D)
#
#  block2d_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2d_expand_conv[0][0]']
#  rmalization)
#
#  block2d_expand_activation   (None, 38, 38, 288)          0         ['block2d_expand_bn[0][0]']
#  (Activation)
#
#  block2d_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2d_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2d_dwconv[0][0]']
#  tion)
#
#  block2d_activation (Activa  (None, 38, 38, 288)          0         ['block2d_bn[0][0]']
#  tion)
#
#  block2d_se_squeeze (Global  (None, 288)                  0         ['block2d_activation[0][0]']
#  AveragePooling2D)
#
#  block2d_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2d_se_squeeze[0][0]']
#  e)
#
#  block2d_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2d_activation[0][0]',
#  y)                                                                  'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2d_se_excite[0][0]']
#  2D)
#
#  block2d_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2d_project_conv[0][0]']
#  ormalization)
#
#  block2d_drop (Dropout)      (None, 38, 38, 48)           0         ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)           (None, 38, 38, 48)           0         ['block2d_drop[0][0]',
#                                                                      'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2d_add[0][0]']
#  D)
#
#  block2e_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2e_expand_conv[0][0]']
#  rmalization)
#
#  block2e_expand_activation   (None, 38, 38, 288)          0         ['block2e_expand_bn[0][0]']
#  (Activation)
#
#  block2e_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2e_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2e_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2e_dwconv[0][0]']
#  tion)
#
#  block2e_activation (Activa  (None, 38, 38, 288)          0         ['block2e_bn[0][0]']
#  tion)
#
#  block2e_se_squeeze (Global  (None, 288)                  0         ['block2e_activation[0][0]']
#  AveragePooling2D)
#
#  block2e_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2e_se_squeeze[0][0]']
#  e)
#
#  block2e_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2e_activation[0][0]',
#  y)                                                                  'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2e_se_excite[0][0]']
#  2D)
#
#  block2e_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2e_project_conv[0][0]']
#  ormalization)
#
#  block2e_drop (Dropout)      (None, 38, 38, 48)           0         ['block2e_project_bn[0][0]']
#
#  block2e_add (Add)           (None, 38, 38, 48)           0         ['block2e_drop[0][0]',
#                                                                      'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2e_add[0][0]']
#  D)
#
#  block2f_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2f_expand_conv[0][0]']
#  rmalization)
#
#  block2f_expand_activation   (None, 38, 38, 288)          0         ['block2f_expand_bn[0][0]']
#  (Activation)
#
#  block2f_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2f_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2f_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2f_dwconv[0][0]']
#  tion)
#
#  block2f_activation (Activa  (None, 38, 38, 288)          0         ['block2f_bn[0][0]']
#  tion)
#
#  block2f_se_squeeze (Global  (None, 288)                  0         ['block2f_activation[0][0]']
#  AveragePooling2D)
#
#  block2f_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2f_se_squeeze[0][0]']
#  e)
#
#  block2f_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2f_se_reshape[0][0]']
#
#  block2f_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2f_se_reduce[0][0]']
#
#  block2f_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2f_activation[0][0]',
#  y)                                                                  'block2f_se_expand[0][0]']
#
#  block2f_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2f_se_excite[0][0]']
#  2D)
#
#  block2f_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2f_project_conv[0][0]']
#  ormalization)
#
#  block2f_drop (Dropout)      (None, 38, 38, 48)           0         ['block2f_project_bn[0][0]']
#
#  block2f_add (Add)           (None, 38, 38, 48)           0         ['block2f_drop[0][0]',
#                                                                      'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2f_add[0][0]']
#  D)
#
#  block2g_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2g_expand_conv[0][0]']
#  rmalization)
#
#  block2g_expand_activation   (None, 38, 38, 288)          0         ['block2g_expand_bn[0][0]']
#  (Activation)
#
#  block2g_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2g_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2g_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2g_dwconv[0][0]']
#  tion)
#
#  block2g_activation (Activa  (None, 38, 38, 288)          0         ['block2g_bn[0][0]']
#  tion)
#
#  block2g_se_squeeze (Global  (None, 288)                  0         ['block2g_activation[0][0]']
#  AveragePooling2D)
#
#  block2g_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2g_se_squeeze[0][0]']
#  e)
#
#  block2g_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2g_se_reshape[0][0]']
#
#  block2g_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2g_se_reduce[0][0]']
#
#  block2g_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2g_activation[0][0]',
#  y)                                                                  'block2g_se_expand[0][0]']
#
#  block2g_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2g_se_excite[0][0]']
#  2D)
#
#  block2g_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2g_project_conv[0][0]']
#  ormalization)
#
#  block2g_drop (Dropout)      (None, 38, 38, 48)           0         ['block2g_project_bn[0][0]']
#
#  block2g_add (Add)           (None, 38, 38, 48)           0         ['block2g_drop[0][0]',
#                                                                      'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2g_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 38, 38, 288)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv_pad (ZeroPa  (None, 41, 41, 288)          0         ['block3a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block3a_dwconv (DepthwiseC  (None, 19, 19, 288)          7200      ['block3a_dwconv_pad[0][0]']
#  onv2D)
#
#  block3a_bn (BatchNormaliza  (None, 19, 19, 288)          1152      ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 19, 19, 288)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 288)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 19, 19, 288)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 19, 19, 80)           23040     ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 19, 19, 80)           320       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 19, 19, 480)          38400     ['block3a_project_bn[0][0]']
#  D)
# ...
#  tion)
#
#  block7a_activation (Activa  (None, 5, 5, 2304)           0         ['block7a_bn[0][0]']
#  tion)
#
#  block7a_se_squeeze (Global  (None, 2304)                 0         ['block7a_activation[0][0]']
#  AveragePooling2D)
#
#  block7a_se_reshape (Reshap  (None, 1, 1, 2304)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 96)             221280    ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 2304)           223488    ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, 5, 5, 2304)           0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, 5, 5, 640)            1474560   ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, 5, 5, 640)            2560      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  block7b_expand_conv (Conv2  (None, 5, 5, 3840)           2457600   ['block7a_project_bn[0][0]']
#  D)
#
#  block7b_expand_bn (BatchNo  (None, 5, 5, 3840)           15360     ['block7b_expand_conv[0][0]']
#  rmalization)
#
#  block7b_expand_activation   (None, 5, 5, 3840)           0         ['block7b_expand_bn[0][0]']
#  (Activation)
#
#  block7b_dwconv (DepthwiseC  (None, 5, 5, 3840)           34560     ['block7b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7b_bn (BatchNormaliza  (None, 5, 5, 3840)           15360     ['block7b_dwconv[0][0]']
#  tion)
#
#  block7b_activation (Activa  (None, 5, 5, 3840)           0         ['block7b_bn[0][0]']
#  tion)
#
#  block7b_se_squeeze (Global  (None, 3840)                 0         ['block7b_activation[0][0]']
#  AveragePooling2D)
#
#  block7b_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7b_se_squeeze[0][0]']
#  e)
#
#  block7b_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multipl  (None, 5, 5, 3840)           0         ['block7b_activation[0][0]',
#  y)                                                                  'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv  (None, 5, 5, 640)            2457600   ['block7b_se_excite[0][0]']
#  2D)
#
#  block7b_project_bn (BatchN  (None, 5, 5, 640)            2560      ['block7b_project_conv[0][0]']
#  ormalization)
#
#  block7b_drop (Dropout)      (None, 5, 5, 640)            0         ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)           (None, 5, 5, 640)            0         ['block7b_drop[0][0]',
#                                                                      'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2  (None, 5, 5, 3840)           2457600   ['block7b_add[0][0]']
#  D)
#
#  block7c_expand_bn (BatchNo  (None, 5, 5, 3840)           15360     ['block7c_expand_conv[0][0]']
#  rmalization)
#
#  block7c_expand_activation   (None, 5, 5, 3840)           0         ['block7c_expand_bn[0][0]']
#  (Activation)
#
#  block7c_dwconv (DepthwiseC  (None, 5, 5, 3840)           34560     ['block7c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7c_bn (BatchNormaliza  (None, 5, 5, 3840)           15360     ['block7c_dwconv[0][0]']
#  tion)
#
#  block7c_activation (Activa  (None, 5, 5, 3840)           0         ['block7c_bn[0][0]']
#  tion)
#
#  block7c_se_squeeze (Global  (None, 3840)                 0         ['block7c_activation[0][0]']
#  AveragePooling2D)
#
#  block7c_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7c_se_squeeze[0][0]']
#  e)
#
#  block7c_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multipl  (None, 5, 5, 3840)           0         ['block7c_activation[0][0]',
#  y)                                                                  'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv  (None, 5, 5, 640)            2457600   ['block7c_se_excite[0][0]']
#  2D)
#
#  block7c_project_bn (BatchN  (None, 5, 5, 640)            2560      ['block7c_project_conv[0][0]']
#  ormalization)
#
#  block7c_drop (Dropout)      (None, 5, 5, 640)            0         ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)           (None, 5, 5, 640)            0         ['block7c_drop[0][0]',
#                                                                      'block7b_add[0][0]']
#
#  block7d_expand_conv (Conv2  (None, 5, 5, 3840)           2457600   ['block7c_add[0][0]']
#  D)
#
#  block7d_expand_bn (BatchNo  (None, 5, 5, 3840)           15360     ['block7d_expand_conv[0][0]']
#  rmalization)
#
#  block7d_expand_activation   (None, 5, 5, 3840)           0         ['block7d_expand_bn[0][0]']
#  (Activation)
#
#  block7d_dwconv (DepthwiseC  (None, 5, 5, 3840)           34560     ['block7d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7d_bn (BatchNormaliza  (None, 5, 5, 3840)           15360     ['block7d_dwconv[0][0]']
#  tion)
#
#  block7d_activation (Activa  (None, 5, 5, 3840)           0         ['block7d_bn[0][0]']
#  tion)
#
#  block7d_se_squeeze (Global  (None, 3840)                 0         ['block7d_activation[0][0]']
#  AveragePooling2D)
#
#  block7d_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7d_se_squeeze[0][0]']
#  e)
#
#  block7d_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7d_se_reshape[0][0]']
#
#  block7d_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7d_se_reduce[0][0]']
#
#  block7d_se_excite (Multipl  (None, 5, 5, 3840)           0         ['block7d_activation[0][0]',
#  y)                                                                  'block7d_se_expand[0][0]']
#
#  block7d_project_conv (Conv  (None, 5, 5, 640)            2457600   ['block7d_se_excite[0][0]']
#  2D)
#
#  block7d_project_bn (BatchN  (None, 5, 5, 640)            2560      ['block7d_project_conv[0][0]']
#  ormalization)
#
#  block7d_drop (Dropout)      (None, 5, 5, 640)            0         ['block7d_project_bn[0][0]']
#
#  block7d_add (Add)           (None, 5, 5, 640)            0         ['block7d_drop[0][0]',
#                                                                      'block7c_add[0][0]']
#
#  top_conv (Conv2D)           (None, 5, 5, 2560)           1638400   ['block7d_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 5, 5, 2560)           10240     ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 5, 5, 2560)           0         ['top_bn[0][0]']
#  )
#
# ==================================================================================================
# Total params: 64097687 (244.51 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 64097687 (244.51 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# **GlobalAveragePooling2D** -> This layer acts similar to the Max Pooling layer in CNNs, the only difference being is that it uses the Average values instead of the Max value while pooling. This really helps in decreasing the computational load on the machine while training.
#
# **Dropout** -> This layer omits some of the neurons at each step from the layer making the neurons more independent from the neibouring neurons. It helps in avoiding overfitting. Neurons to be ommitted are selected at random. The rate parameter is the liklihood of a neuron activation being set to 0, thus dropping out the neuron
#
# **Dense** -> This is the output layer which classifies the image into 1 of the 4 possible classes. It uses the softmax function which is a generalization of the sigmoid function.

# %%
model = effnet.output
model = tf.keras.layers.GlobalAveragePooling2D()(model)
model = tf.keras.layers.Dropout(rate=0.5)(model)
model = tf.keras.layers.Dense(4,activation='softmax')(model)
model = tf.keras.models.Model(inputs=effnet.input, outputs = model)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 150, 150, 3)          0         ['input_1[0][0]']
#
#  normalization (Normalizati  (None, 150, 150, 3)          7         ['rescaling[0][0]']
#  on)
#
#  rescaling_1 (Rescaling)     (None, 150, 150, 3)          0         ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 151, 151, 3)          0         ['rescaling_1[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 75, 75, 64)           1728      ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 75, 75, 64)           256       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 75, 75, 64)           0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 75, 75, 64)           576       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 75, 75, 64)           256       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 75, 75, 64)           0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 64)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 64)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 16)             1040      ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 64)             1088      ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 75, 75, 64)           0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 75, 75, 32)           2048      ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 75, 75, 32)           128       ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1b_dwconv (DepthwiseC  (None, 75, 75, 32)           288       ['block1a_project_bn[0][0]']
#  onv2D)
#
#  block1b_bn (BatchNormaliza  (None, 75, 75, 32)           128       ['block1b_dwconv[0][0]']
#  tion)
#
#  block1b_activation (Activa  (None, 75, 75, 32)           0         ['block1b_bn[0][0]']
#  tion)
#
#  block1b_se_squeeze (Global  (None, 32)                   0         ['block1b_activation[0][0]']
#  AveragePooling2D)
#
#  block1b_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1b_se_squeeze[0][0]']
#  e)
#
#  block1b_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multipl  (None, 75, 75, 32)           0         ['block1b_activation[0][0]',
#  y)                                                                  'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv  (None, 75, 75, 32)           1024      ['block1b_se_excite[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 75, 75, 32)           128       ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_drop (Dropout)      (None, 75, 75, 32)           0         ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)           (None, 75, 75, 32)           0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseC  (None, 75, 75, 32)           288       ['block1b_add[0][0]']
#  onv2D)
#
#  block1c_bn (BatchNormaliza  (None, 75, 75, 32)           128       ['block1c_dwconv[0][0]']
#  tion)
#
#  block1c_activation (Activa  (None, 75, 75, 32)           0         ['block1c_bn[0][0]']
#  tion)
#
#  block1c_se_squeeze (Global  (None, 32)                   0         ['block1c_activation[0][0]']
#  AveragePooling2D)
#
#  block1c_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1c_se_squeeze[0][0]']
#  e)
#
#  block1c_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multipl  (None, 75, 75, 32)           0         ['block1c_activation[0][0]',
#  y)                                                                  'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv  (None, 75, 75, 32)           1024      ['block1c_se_excite[0][0]']
#  2D)
#
#  block1c_project_bn (BatchN  (None, 75, 75, 32)           128       ['block1c_project_conv[0][0]']
#  ormalization)
#
#  block1c_drop (Dropout)      (None, 75, 75, 32)           0         ['block1c_project_bn[0][0]']
#
#  block1c_add (Add)           (None, 75, 75, 32)           0         ['block1c_drop[0][0]',
#                                                                      'block1b_add[0][0]']
#
#  block1d_dwconv (DepthwiseC  (None, 75, 75, 32)           288       ['block1c_add[0][0]']
#  onv2D)
#
#  block1d_bn (BatchNormaliza  (None, 75, 75, 32)           128       ['block1d_dwconv[0][0]']
#  tion)
#
#  block1d_activation (Activa  (None, 75, 75, 32)           0         ['block1d_bn[0][0]']
#  tion)
#
#  block1d_se_squeeze (Global  (None, 32)                   0         ['block1d_activation[0][0]']
#  AveragePooling2D)
#
#  block1d_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1d_se_squeeze[0][0]']
#  e)
#
#  block1d_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1d_se_reshape[0][0]']
#
#  block1d_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1d_se_reduce[0][0]']
#
#  block1d_se_excite (Multipl  (None, 75, 75, 32)           0         ['block1d_activation[0][0]',
#  y)                                                                  'block1d_se_expand[0][0]']
#
#  block1d_project_conv (Conv  (None, 75, 75, 32)           1024      ['block1d_se_excite[0][0]']
#  2D)
#
#  block1d_project_bn (BatchN  (None, 75, 75, 32)           128       ['block1d_project_conv[0][0]']
#  ormalization)
#
#  block1d_drop (Dropout)      (None, 75, 75, 32)           0         ['block1d_project_bn[0][0]']
#
#  block1d_add (Add)           (None, 75, 75, 32)           0         ['block1d_drop[0][0]',
#                                                                      'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 75, 75, 192)          6144      ['block1d_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 75, 75, 192)          768       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 75, 75, 192)          0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv_pad (ZeroPa  (None, 77, 77, 192)          0         ['block2a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block2a_dwconv (DepthwiseC  (None, 38, 38, 192)          1728      ['block2a_dwconv_pad[0][0]']
#  onv2D)
#
#  block2a_bn (BatchNormaliza  (None, 38, 38, 192)          768       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 38, 38, 192)          0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 192)                  0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 38, 38, 192)          0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 38, 38, 48)           9216      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 38, 38, 288)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 38, 38, 288)          0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 288)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 38, 38, 48)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 38, 38, 48)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 38, 38, 288)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2c_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2c_dwconv[0][0]']
#  tion)
#
#  block2c_activation (Activa  (None, 38, 38, 288)          0         ['block2c_bn[0][0]']
#  tion)
#
#  block2c_se_squeeze (Global  (None, 288)                  0         ['block2c_activation[0][0]']
#  AveragePooling2D)
#
#  block2c_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2c_se_squeeze[0][0]']
#  e)
#
#  block2c_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2c_activation[0][0]',
#  y)                                                                  'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2c_se_excite[0][0]']
#  2D)
#
#  block2c_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 38, 38, 48)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 38, 38, 48)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2c_add[0][0]']
#  D)
#
#  block2d_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2d_expand_conv[0][0]']
#  rmalization)
#
#  block2d_expand_activation   (None, 38, 38, 288)          0         ['block2d_expand_bn[0][0]']
#  (Activation)
#
#  block2d_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2d_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2d_dwconv[0][0]']
#  tion)
#
#  block2d_activation (Activa  (None, 38, 38, 288)          0         ['block2d_bn[0][0]']
#  tion)
#
#  block2d_se_squeeze (Global  (None, 288)                  0         ['block2d_activation[0][0]']
#  AveragePooling2D)
#
#  block2d_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2d_se_squeeze[0][0]']
#  e)
#
#  block2d_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2d_activation[0][0]',
#  y)                                                                  'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2d_se_excite[0][0]']
#  2D)
#
#  block2d_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2d_project_conv[0][0]']
#  ormalization)
#
#  block2d_drop (Dropout)      (None, 38, 38, 48)           0         ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)           (None, 38, 38, 48)           0         ['block2d_drop[0][0]',
#                                                                      'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2d_add[0][0]']
#  D)
#
#  block2e_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2e_expand_conv[0][0]']
#  rmalization)
#
#  block2e_expand_activation   (None, 38, 38, 288)          0         ['block2e_expand_bn[0][0]']
#  (Activation)
#
#  block2e_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2e_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2e_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2e_dwconv[0][0]']
#  tion)
#
#  block2e_activation (Activa  (None, 38, 38, 288)          0         ['block2e_bn[0][0]']
#  tion)
#
#  block2e_se_squeeze (Global  (None, 288)                  0         ['block2e_activation[0][0]']
#  AveragePooling2D)
#
#  block2e_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2e_se_squeeze[0][0]']
#  e)
#
#  block2e_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2e_activation[0][0]',
#  y)                                                                  'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2e_se_excite[0][0]']
#  2D)
#
#  block2e_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2e_project_conv[0][0]']
#  ormalization)
#
#  block2e_drop (Dropout)      (None, 38, 38, 48)           0         ['block2e_project_bn[0][0]']
#
#  block2e_add (Add)           (None, 38, 38, 48)           0         ['block2e_drop[0][0]',
#                                                                      'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2e_add[0][0]']
#  D)
#
#  block2f_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2f_expand_conv[0][0]']
#  rmalization)
#
#  block2f_expand_activation   (None, 38, 38, 288)          0         ['block2f_expand_bn[0][0]']
#  (Activation)
#
#  block2f_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2f_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2f_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2f_dwconv[0][0]']
#  tion)
#
#  block2f_activation (Activa  (None, 38, 38, 288)          0         ['block2f_bn[0][0]']
#  tion)
#
#  block2f_se_squeeze (Global  (None, 288)                  0         ['block2f_activation[0][0]']
#  AveragePooling2D)
#
#  block2f_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2f_se_squeeze[0][0]']
#  e)
#
#  block2f_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2f_se_reshape[0][0]']
#
#  block2f_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2f_se_reduce[0][0]']
#
#  block2f_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2f_activation[0][0]',
#  y)                                                                  'block2f_se_expand[0][0]']
#
#  block2f_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2f_se_excite[0][0]']
#  2D)
#
#  block2f_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2f_project_conv[0][0]']
#  ormalization)
#
#  block2f_drop (Dropout)      (None, 38, 38, 48)           0         ['block2f_project_bn[0][0]']
#
#  block2f_add (Add)           (None, 38, 38, 48)           0         ['block2f_drop[0][0]',
#                                                                      'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2f_add[0][0]']
#  D)
#
#  block2g_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2g_expand_conv[0][0]']
#  rmalization)
#
#  block2g_expand_activation   (None, 38, 38, 288)          0         ['block2g_expand_bn[0][0]']
#  (Activation)
#
#  block2g_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2g_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2g_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2g_dwconv[0][0]']
#  tion)
#
#  block2g_activation (Activa  (None, 38, 38, 288)          0         ['block2g_bn[0][0]']
#  tion)
#
#  block2g_se_squeeze (Global  (None, 288)                  0         ['block2g_activation[0][0]']
#  AveragePooling2D)
#
#  block2g_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2g_se_squeeze[0][0]']
#  e)
#
#  block2g_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2g_se_reshape[0][0]']
#
#  block2g_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2g_se_reduce[0][0]']
#
#  block2g_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2g_activation[0][0]',
#  y)                                                                  'block2g_se_expand[0][0]']
#
#  block2g_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2g_se_excite[0][0]']
#  2D)
#
#  block2g_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2g_project_conv[0][0]']
#  ormalization)
#
#  block2g_drop (Dropout)      (None, 38, 38, 48)           0         ['block2g_project_bn[0][0]']
#
#  block2g_add (Add)           (None, 38, 38, 48)           0         ['block2g_drop[0][0]',
#                                                                      'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2g_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 38, 38, 288)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv_pad (ZeroPa  (None, 41, 41, 288)          0         ['block3a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block3a_dwconv (DepthwiseC  (None, 19, 19, 288)          7200      ['block3a_dwconv_pad[0][0]']
#  onv2D)
#
#  block3a_bn (BatchNormaliza  (None, 19, 19, 288)          1152      ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 19, 19, 288)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 288)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 19, 19, 288)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 19, 19, 80)           23040     ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 19, 19, 80)           320       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 19, 19, 480)          38400     ['block3a_project_bn[0][0]']
#  D)
# ...
#  block7a_se_reshape (Reshap  (None, 1, 1, 2304)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 96)             221280    ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 2304)           223488    ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, 5, 5, 2304)           0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, 5, 5, 640)            1474560   ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, 5, 5, 640)            2560      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  block7b_expand_conv (Conv2  (None, 5, 5, 3840)           2457600   ['block7a_project_bn[0][0]']
#  D)
#
#  block7b_expand_bn (BatchNo  (None, 5, 5, 3840)           15360     ['block7b_expand_conv[0][0]']
#  rmalization)
#
#  block7b_expand_activation   (None, 5, 5, 3840)           0         ['block7b_expand_bn[0][0]']
#  (Activation)
#
#  block7b_dwconv (DepthwiseC  (None, 5, 5, 3840)           34560     ['block7b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7b_bn (BatchNormaliza  (None, 5, 5, 3840)           15360     ['block7b_dwconv[0][0]']
#  tion)
#
#  block7b_activation (Activa  (None, 5, 5, 3840)           0         ['block7b_bn[0][0]']
#  tion)
#
#  block7b_se_squeeze (Global  (None, 3840)                 0         ['block7b_activation[0][0]']
#  AveragePooling2D)
#
#  block7b_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7b_se_squeeze[0][0]']
#  e)
#
#  block7b_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multipl  (None, 5, 5, 3840)           0         ['block7b_activation[0][0]',
#  y)                                                                  'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv  (None, 5, 5, 640)            2457600   ['block7b_se_excite[0][0]']
#  2D)
#
#  block7b_project_bn (BatchN  (None, 5, 5, 640)            2560      ['block7b_project_conv[0][0]']
#  ormalization)
#
#  block7b_drop (Dropout)      (None, 5, 5, 640)            0         ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)           (None, 5, 5, 640)            0         ['block7b_drop[0][0]',
#                                                                      'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2  (None, 5, 5, 3840)           2457600   ['block7b_add[0][0]']
#  D)
#
#  block7c_expand_bn (BatchNo  (None, 5, 5, 3840)           15360     ['block7c_expand_conv[0][0]']
#  rmalization)
#
#  block7c_expand_activation   (None, 5, 5, 3840)           0         ['block7c_expand_bn[0][0]']
#  (Activation)
#
#  block7c_dwconv (DepthwiseC  (None, 5, 5, 3840)           34560     ['block7c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7c_bn (BatchNormaliza  (None, 5, 5, 3840)           15360     ['block7c_dwconv[0][0]']
#  tion)
#
#  block7c_activation (Activa  (None, 5, 5, 3840)           0         ['block7c_bn[0][0]']
#  tion)
#
#  block7c_se_squeeze (Global  (None, 3840)                 0         ['block7c_activation[0][0]']
#  AveragePooling2D)
#
#  block7c_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7c_se_squeeze[0][0]']
#  e)
#
#  block7c_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multipl  (None, 5, 5, 3840)           0         ['block7c_activation[0][0]',
#  y)                                                                  'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv  (None, 5, 5, 640)            2457600   ['block7c_se_excite[0][0]']
#  2D)
#
#  block7c_project_bn (BatchN  (None, 5, 5, 640)            2560      ['block7c_project_conv[0][0]']
#  ormalization)
#
#  block7c_drop (Dropout)      (None, 5, 5, 640)            0         ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)           (None, 5, 5, 640)            0         ['block7c_drop[0][0]',
#                                                                      'block7b_add[0][0]']
#
#  block7d_expand_conv (Conv2  (None, 5, 5, 3840)           2457600   ['block7c_add[0][0]']
#  D)
#
#  block7d_expand_bn (BatchNo  (None, 5, 5, 3840)           15360     ['block7d_expand_conv[0][0]']
#  rmalization)
#
#  block7d_expand_activation   (None, 5, 5, 3840)           0         ['block7d_expand_bn[0][0]']
#  (Activation)
#
#  block7d_dwconv (DepthwiseC  (None, 5, 5, 3840)           34560     ['block7d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7d_bn (BatchNormaliza  (None, 5, 5, 3840)           15360     ['block7d_dwconv[0][0]']
#  tion)
#
#  block7d_activation (Activa  (None, 5, 5, 3840)           0         ['block7d_bn[0][0]']
#  tion)
#
#  block7d_se_squeeze (Global  (None, 3840)                 0         ['block7d_activation[0][0]']
#  AveragePooling2D)
#
#  block7d_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7d_se_squeeze[0][0]']
#  e)
#
#  block7d_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7d_se_reshape[0][0]']
#
#  block7d_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7d_se_reduce[0][0]']
#
#  block7d_se_excite (Multipl  (None, 5, 5, 3840)           0         ['block7d_activation[0][0]',
#  y)                                                                  'block7d_se_expand[0][0]']
#
#  block7d_project_conv (Conv  (None, 5, 5, 640)            2457600   ['block7d_se_excite[0][0]']
#  2D)
#
#  block7d_project_bn (BatchN  (None, 5, 5, 640)            2560      ['block7d_project_conv[0][0]']
#  ormalization)
#
#  block7d_drop (Dropout)      (None, 5, 5, 640)            0         ['block7d_project_bn[0][0]']
#
#  block7d_add (Add)           (None, 5, 5, 640)            0         ['block7d_drop[0][0]',
#                                                                      'block7c_add[0][0]']
#
#  top_conv (Conv2D)           (None, 5, 5, 2560)           1638400   ['block7d_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 5, 5, 2560)           10240     ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 5, 5, 2560)           0         ['top_bn[0][0]']
#  )
#
#  global_average_pooling2d (  (None, 2560)                 0         ['top_activation[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2560)                 0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 4)                    10244     ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 64107931 (244.55 MB)
# Trainable params: 10244 (40.02 KB)
# Non-trainable params: 64097687 (244.51 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# "A callback is a set of functions to be applied at given stages of the training procedure. You can use callbacks to get a view on internal states and statistics of the model during training."
#
# In this notebook, I'll be using **TensorBoard**, **ModelCheckpoint** and **ReduceLROnPlateau** callback functions

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("effnet.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= ['accuracy'])

# %%
history = model.fit(X_train,y_train,validation_split=0.1, epochs =12, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/12
# 85/85 [==============================] - ETA: 0s - loss: 1.0052 - accuracy: 0.5743
# Epoch 1: val_accuracy improved from -inf to 0.74000, saving model to effnet.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 85/85 [==============================] - 56s 335ms/step - loss: 1.0052 - accuracy: 0.5743 - val_loss: 0.6916 - val_accuracy: 0.7400 - lr: 0.0010
# Epoch 2/12
# 84/85 [============================>.] - ETA: 0s - loss: 0.7378 - accuracy: 0.7065
# Epoch 2: val_accuracy improved from 0.74000 to 0.79000, saving model to effnet.h5
# 85/85 [==============================] - 19s 224ms/step - loss: 0.7373 - accuracy: 0.7065 - val_loss: 0.5824 - val_accuracy: 0.7900 - lr: 0.0010
# Epoch 3/12
# 85/85 [==============================] - ETA: 0s - loss: 0.6511 - accuracy: 0.7481
# Epoch 3: val_accuracy improved from 0.79000 to 0.80333, saving model to effnet.h5
# 85/85 [==============================] - 19s 222ms/step - loss: 0.6511 - accuracy: 0.7481 - val_loss: 0.5443 - val_accuracy: 0.8033 - lr: 0.0010
# Epoch 4/12
# 84/85 [============================>.] - ETA: 0s - loss: 0.6090 - accuracy: 0.7675
# Epoch 4: val_accuracy improved from 0.80333 to 0.81333, saving model to effnet.h5
# 85/85 [==============================] - 18s 216ms/step - loss: 0.6087 - accuracy: 0.7675 - val_loss: 0.5101 - val_accuracy: 0.8133 - lr: 0.0010
# Epoch 5/12
# 84/85 [============================>.] - ETA: 0s - loss: 0.5653 - accuracy: 0.7820
# Epoch 5: val_accuracy did not improve from 0.81333
# 85/85 [==============================] - 17s 199ms/step - loss: 0.5649 - accuracy: 0.7823 - val_loss: 0.4864 - val_accuracy: 0.8133 - lr: 0.0010
# Epoch 6/12
# 84/85 [============================>.] - ETA: 0s - loss: 0.5445 - accuracy: 0.8017
# Epoch 6: val_accuracy improved from 0.81333 to 0.83000, saving model to effnet.h5
# 85/85 [==============================] - 19s 227ms/step - loss: 0.5446 - accuracy: 0.8013 - val_loss: 0.4711 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 7/12
# 84/85 [============================>.] - ETA: 0s - loss: 0.5218 - accuracy: 0.8025
# Epoch 7: val_accuracy did not improve from 0.83000
# 85/85 [==============================] - 17s 201ms/step - loss: 0.5212 - accuracy: 0.8027 - val_loss: 0.4597 - val_accuracy: 0.8233 - lr: 0.0010
# Epoch 8/12
# 84/85 [============================>.] - ETA: 0s - loss: 0.5045 - accuracy: 0.8125
# Epoch 8: val_accuracy did not improve from 0.83000
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 85/85 [==============================] - 18s 211ms/step - loss: 0.5039 - accuracy: 0.8128 - val_loss: 0.4441 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 9/12
# 84/85 [============================>.] - ETA: 0s - loss: 0.4901 - accuracy: 0.8121
# Epoch 9: val_accuracy improved from 0.83000 to 0.83667, saving model to effnet.h5
# 85/85 [==============================] - 20s 234ms/step - loss: 0.4898 - accuracy: 0.8124 - val_loss: 0.4335 - val_accuracy: 0.8367 - lr: 3.0000e-04
# Epoch 10/12
# 84/85 [============================>.] - ETA: 0s - loss: 0.4873 - accuracy: 0.8121
# Epoch 10: val_accuracy did not improve from 0.83667
# 85/85 [==============================] - 18s 213ms/step - loss: 0.4868 - accuracy: 0.8124 - val_loss: 0.4409 - val_accuracy: 0.8300 - lr: 3.0000e-04
# Epoch 11/12
# 84/85 [============================>.] - ETA: 0s - loss: 0.4817 - accuracy: 0.8263
# Epoch 11: val_accuracy did not improve from 0.83667
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 85/85 [==============================] - 18s 213ms/step - loss: 0.4828 - accuracy: 0.8258 - val_loss: 0.4370 - val_accuracy: 0.8267 - lr: 3.0000e-04
# Epoch 12/12
# 85/85 [==============================] - ETA: 0s - loss: 0.4729 - accuracy: 0.8262
# Epoch 12: val_accuracy did not improve from 0.83667
# 85/85 [==============================] - 18s 213ms/step - loss: 0.4729 - accuracy: 0.8262 - val_loss: 0.4326 - val_accuracy: 0.8267 - lr: 9.0000e-05

# %% [markdown]
# ### **Fine-Tuning**

# %%
from tensorflow.keras.optimizers import Adam

# %%
effnet.trainable = True
model.compile(optimizer=Adam(learning_rate=1e-5),
              loss='categorical_crossentropy', metrics= ['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 150, 150, 3)          0         ['input_1[0][0]']
#
#  normalization (Normalizati  (None, 150, 150, 3)          7         ['rescaling[0][0]']
#  on)
#
#  rescaling_1 (Rescaling)     (None, 150, 150, 3)          0         ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 151, 151, 3)          0         ['rescaling_1[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 75, 75, 64)           1728      ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 75, 75, 64)           256       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 75, 75, 64)           0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 75, 75, 64)           576       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 75, 75, 64)           256       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 75, 75, 64)           0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 64)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 64)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 16)             1040      ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 64)             1088      ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 75, 75, 64)           0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 75, 75, 32)           2048      ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 75, 75, 32)           128       ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1b_dwconv (DepthwiseC  (None, 75, 75, 32)           288       ['block1a_project_bn[0][0]']
#  onv2D)
#
#  block1b_bn (BatchNormaliza  (None, 75, 75, 32)           128       ['block1b_dwconv[0][0]']
#  tion)
#
#  block1b_activation (Activa  (None, 75, 75, 32)           0         ['block1b_bn[0][0]']
#  tion)
#
#  block1b_se_squeeze (Global  (None, 32)                   0         ['block1b_activation[0][0]']
#  AveragePooling2D)
#
#  block1b_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1b_se_squeeze[0][0]']
#  e)
#
#  block1b_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multipl  (None, 75, 75, 32)           0         ['block1b_activation[0][0]',
#  y)                                                                  'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv  (None, 75, 75, 32)           1024      ['block1b_se_excite[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 75, 75, 32)           128       ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_drop (Dropout)      (None, 75, 75, 32)           0         ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)           (None, 75, 75, 32)           0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseC  (None, 75, 75, 32)           288       ['block1b_add[0][0]']
#  onv2D)
#
#  block1c_bn (BatchNormaliza  (None, 75, 75, 32)           128       ['block1c_dwconv[0][0]']
#  tion)
#
#  block1c_activation (Activa  (None, 75, 75, 32)           0         ['block1c_bn[0][0]']
#  tion)
#
#  block1c_se_squeeze (Global  (None, 32)                   0         ['block1c_activation[0][0]']
#  AveragePooling2D)
#
#  block1c_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1c_se_squeeze[0][0]']
#  e)
#
#  block1c_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multipl  (None, 75, 75, 32)           0         ['block1c_activation[0][0]',
#  y)                                                                  'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv  (None, 75, 75, 32)           1024      ['block1c_se_excite[0][0]']
#  2D)
#
#  block1c_project_bn (BatchN  (None, 75, 75, 32)           128       ['block1c_project_conv[0][0]']
#  ormalization)
#
#  block1c_drop (Dropout)      (None, 75, 75, 32)           0         ['block1c_project_bn[0][0]']
#
#  block1c_add (Add)           (None, 75, 75, 32)           0         ['block1c_drop[0][0]',
#                                                                      'block1b_add[0][0]']
#
#  block1d_dwconv (DepthwiseC  (None, 75, 75, 32)           288       ['block1c_add[0][0]']
#  onv2D)
#
#  block1d_bn (BatchNormaliza  (None, 75, 75, 32)           128       ['block1d_dwconv[0][0]']
#  tion)
#
#  block1d_activation (Activa  (None, 75, 75, 32)           0         ['block1d_bn[0][0]']
#  tion)
#
#  block1d_se_squeeze (Global  (None, 32)                   0         ['block1d_activation[0][0]']
#  AveragePooling2D)
#
#  block1d_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1d_se_squeeze[0][0]']
#  e)
#
#  block1d_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1d_se_reshape[0][0]']
#
#  block1d_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1d_se_reduce[0][0]']
#
#  block1d_se_excite (Multipl  (None, 75, 75, 32)           0         ['block1d_activation[0][0]',
#  y)                                                                  'block1d_se_expand[0][0]']
#
#  block1d_project_conv (Conv  (None, 75, 75, 32)           1024      ['block1d_se_excite[0][0]']
#  2D)
#
#  block1d_project_bn (BatchN  (None, 75, 75, 32)           128       ['block1d_project_conv[0][0]']
#  ormalization)
#
#  block1d_drop (Dropout)      (None, 75, 75, 32)           0         ['block1d_project_bn[0][0]']
#
#  block1d_add (Add)           (None, 75, 75, 32)           0         ['block1d_drop[0][0]',
#                                                                      'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 75, 75, 192)          6144      ['block1d_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 75, 75, 192)          768       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 75, 75, 192)          0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv_pad (ZeroPa  (None, 77, 77, 192)          0         ['block2a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block2a_dwconv (DepthwiseC  (None, 38, 38, 192)          1728      ['block2a_dwconv_pad[0][0]']
#  onv2D)
#
#  block2a_bn (BatchNormaliza  (None, 38, 38, 192)          768       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 38, 38, 192)          0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 192)                  0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 38, 38, 192)          0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 38, 38, 48)           9216      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 38, 38, 288)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 38, 38, 288)          0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 288)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 38, 38, 48)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 38, 38, 48)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 38, 38, 288)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2c_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2c_dwconv[0][0]']
#  tion)
#
#  block2c_activation (Activa  (None, 38, 38, 288)          0         ['block2c_bn[0][0]']
#  tion)
#
#  block2c_se_squeeze (Global  (None, 288)                  0         ['block2c_activation[0][0]']
#  AveragePooling2D)
#
#  block2c_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2c_se_squeeze[0][0]']
#  e)
#
#  block2c_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2c_activation[0][0]',
#  y)                                                                  'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2c_se_excite[0][0]']
#  2D)
#
#  block2c_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 38, 38, 48)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 38, 38, 48)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2c_add[0][0]']
#  D)
#
#  block2d_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2d_expand_conv[0][0]']
#  rmalization)
#
#  block2d_expand_activation   (None, 38, 38, 288)          0         ['block2d_expand_bn[0][0]']
#  (Activation)
#
#  block2d_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2d_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2d_dwconv[0][0]']
#  tion)
#
#  block2d_activation (Activa  (None, 38, 38, 288)          0         ['block2d_bn[0][0]']
#  tion)
#
#  block2d_se_squeeze (Global  (None, 288)                  0         ['block2d_activation[0][0]']
#  AveragePooling2D)
#
#  block2d_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2d_se_squeeze[0][0]']
#  e)
#
#  block2d_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2d_activation[0][0]',
#  y)                                                                  'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2d_se_excite[0][0]']
#  2D)
#
#  block2d_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2d_project_conv[0][0]']
#  ormalization)
#
#  block2d_drop (Dropout)      (None, 38, 38, 48)           0         ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)           (None, 38, 38, 48)           0         ['block2d_drop[0][0]',
#                                                                      'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2d_add[0][0]']
#  D)
#
#  block2e_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2e_expand_conv[0][0]']
#  rmalization)
#
#  block2e_expand_activation   (None, 38, 38, 288)          0         ['block2e_expand_bn[0][0]']
#  (Activation)
#
#  block2e_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2e_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2e_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2e_dwconv[0][0]']
#  tion)
#
#  block2e_activation (Activa  (None, 38, 38, 288)          0         ['block2e_bn[0][0]']
#  tion)
#
#  block2e_se_squeeze (Global  (None, 288)                  0         ['block2e_activation[0][0]']
#  AveragePooling2D)
#
#  block2e_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2e_se_squeeze[0][0]']
#  e)
#
#  block2e_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2e_activation[0][0]',
#  y)                                                                  'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2e_se_excite[0][0]']
#  2D)
#
#  block2e_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2e_project_conv[0][0]']
#  ormalization)
#
#  block2e_drop (Dropout)      (None, 38, 38, 48)           0         ['block2e_project_bn[0][0]']
#
#  block2e_add (Add)           (None, 38, 38, 48)           0         ['block2e_drop[0][0]',
#                                                                      'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2e_add[0][0]']
#  D)
#
#  block2f_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2f_expand_conv[0][0]']
#  rmalization)
#
#  block2f_expand_activation   (None, 38, 38, 288)          0         ['block2f_expand_bn[0][0]']
#  (Activation)
#
#  block2f_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2f_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2f_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2f_dwconv[0][0]']
#  tion)
#
#  block2f_activation (Activa  (None, 38, 38, 288)          0         ['block2f_bn[0][0]']
#  tion)
#
#  block2f_se_squeeze (Global  (None, 288)                  0         ['block2f_activation[0][0]']
#  AveragePooling2D)
#
#  block2f_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2f_se_squeeze[0][0]']
#  e)
#
#  block2f_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2f_se_reshape[0][0]']
#
#  block2f_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2f_se_reduce[0][0]']
#
#  block2f_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2f_activation[0][0]',
#  y)                                                                  'block2f_se_expand[0][0]']
#
#  block2f_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2f_se_excite[0][0]']
#  2D)
#
#  block2f_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2f_project_conv[0][0]']
#  ormalization)
#
#  block2f_drop (Dropout)      (None, 38, 38, 48)           0         ['block2f_project_bn[0][0]']
#
#  block2f_add (Add)           (None, 38, 38, 48)           0         ['block2f_drop[0][0]',
#                                                                      'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2f_add[0][0]']
#  D)
#
#  block2g_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block2g_expand_conv[0][0]']
#  rmalization)
#
#  block2g_expand_activation   (None, 38, 38, 288)          0         ['block2g_expand_bn[0][0]']
#  (Activation)
#
#  block2g_dwconv (DepthwiseC  (None, 38, 38, 288)          2592      ['block2g_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2g_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block2g_dwconv[0][0]']
#  tion)
#
#  block2g_activation (Activa  (None, 38, 38, 288)          0         ['block2g_bn[0][0]']
#  tion)
#
#  block2g_se_squeeze (Global  (None, 288)                  0         ['block2g_activation[0][0]']
#  AveragePooling2D)
#
#  block2g_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2g_se_squeeze[0][0]']
#  e)
#
#  block2g_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2g_se_reshape[0][0]']
#
#  block2g_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2g_se_reduce[0][0]']
#
#  block2g_se_excite (Multipl  (None, 38, 38, 288)          0         ['block2g_activation[0][0]',
#  y)                                                                  'block2g_se_expand[0][0]']
#
#  block2g_project_conv (Conv  (None, 38, 38, 48)           13824     ['block2g_se_excite[0][0]']
#  2D)
#
#  block2g_project_bn (BatchN  (None, 38, 38, 48)           192       ['block2g_project_conv[0][0]']
#  ormalization)
#
#  block2g_drop (Dropout)      (None, 38, 38, 48)           0         ['block2g_project_bn[0][0]']
#
#  block2g_add (Add)           (None, 38, 38, 48)           0         ['block2g_drop[0][0]',
#                                                                      'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block2g_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 38, 38, 288)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv_pad (ZeroPa  (None, 41, 41, 288)          0         ['block3a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block3a_dwconv (DepthwiseC  (None, 19, 19, 288)          7200      ['block3a_dwconv_pad[0][0]']
#  onv2D)
#
#  block3a_bn (BatchNormaliza  (None, 19, 19, 288)          1152      ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 19, 19, 288)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 288)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 19, 19, 288)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 19, 19, 80)           23040     ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 19, 19, 80)           320       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 19, 19, 480)          38400     ['block3a_project_bn[0][0]']
#  D)
# ...
#  block7a_se_reshape (Reshap  (None, 1, 1, 2304)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 96)             221280    ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 2304)           223488    ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, 5, 5, 2304)           0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, 5, 5, 640)            1474560   ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, 5, 5, 640)            2560      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  block7b_expand_conv (Conv2  (None, 5, 5, 3840)           2457600   ['block7a_project_bn[0][0]']
#  D)
#
#  block7b_expand_bn (BatchNo  (None, 5, 5, 3840)           15360     ['block7b_expand_conv[0][0]']
#  rmalization)
#
#  block7b_expand_activation   (None, 5, 5, 3840)           0         ['block7b_expand_bn[0][0]']
#  (Activation)
#
#  block7b_dwconv (DepthwiseC  (None, 5, 5, 3840)           34560     ['block7b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7b_bn (BatchNormaliza  (None, 5, 5, 3840)           15360     ['block7b_dwconv[0][0]']
#  tion)
#
#  block7b_activation (Activa  (None, 5, 5, 3840)           0         ['block7b_bn[0][0]']
#  tion)
#
#  block7b_se_squeeze (Global  (None, 3840)                 0         ['block7b_activation[0][0]']
#  AveragePooling2D)
#
#  block7b_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7b_se_squeeze[0][0]']
#  e)
#
#  block7b_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multipl  (None, 5, 5, 3840)           0         ['block7b_activation[0][0]',
#  y)                                                                  'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv  (None, 5, 5, 640)            2457600   ['block7b_se_excite[0][0]']
#  2D)
#
#  block7b_project_bn (BatchN  (None, 5, 5, 640)            2560      ['block7b_project_conv[0][0]']
#  ormalization)
#
#  block7b_drop (Dropout)      (None, 5, 5, 640)            0         ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)           (None, 5, 5, 640)            0         ['block7b_drop[0][0]',
#                                                                      'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2  (None, 5, 5, 3840)           2457600   ['block7b_add[0][0]']
#  D)
#
#  block7c_expand_bn (BatchNo  (None, 5, 5, 3840)           15360     ['block7c_expand_conv[0][0]']
#  rmalization)
#
#  block7c_expand_activation   (None, 5, 5, 3840)           0         ['block7c_expand_bn[0][0]']
#  (Activation)
#
#  block7c_dwconv (DepthwiseC  (None, 5, 5, 3840)           34560     ['block7c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7c_bn (BatchNormaliza  (None, 5, 5, 3840)           15360     ['block7c_dwconv[0][0]']
#  tion)
#
#  block7c_activation (Activa  (None, 5, 5, 3840)           0         ['block7c_bn[0][0]']
#  tion)
#
#  block7c_se_squeeze (Global  (None, 3840)                 0         ['block7c_activation[0][0]']
#  AveragePooling2D)
#
#  block7c_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7c_se_squeeze[0][0]']
#  e)
#
#  block7c_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multipl  (None, 5, 5, 3840)           0         ['block7c_activation[0][0]',
#  y)                                                                  'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv  (None, 5, 5, 640)            2457600   ['block7c_se_excite[0][0]']
#  2D)
#
#  block7c_project_bn (BatchN  (None, 5, 5, 640)            2560      ['block7c_project_conv[0][0]']
#  ormalization)
#
#  block7c_drop (Dropout)      (None, 5, 5, 640)            0         ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)           (None, 5, 5, 640)            0         ['block7c_drop[0][0]',
#                                                                      'block7b_add[0][0]']
#
#  block7d_expand_conv (Conv2  (None, 5, 5, 3840)           2457600   ['block7c_add[0][0]']
#  D)
#
#  block7d_expand_bn (BatchNo  (None, 5, 5, 3840)           15360     ['block7d_expand_conv[0][0]']
#  rmalization)
#
#  block7d_expand_activation   (None, 5, 5, 3840)           0         ['block7d_expand_bn[0][0]']
#  (Activation)
#
#  block7d_dwconv (DepthwiseC  (None, 5, 5, 3840)           34560     ['block7d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7d_bn (BatchNormaliza  (None, 5, 5, 3840)           15360     ['block7d_dwconv[0][0]']
#  tion)
#
#  block7d_activation (Activa  (None, 5, 5, 3840)           0         ['block7d_bn[0][0]']
#  tion)
#
#  block7d_se_squeeze (Global  (None, 3840)                 0         ['block7d_activation[0][0]']
#  AveragePooling2D)
#
#  block7d_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7d_se_squeeze[0][0]']
#  e)
#
#  block7d_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7d_se_reshape[0][0]']
#
#  block7d_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7d_se_reduce[0][0]']
#
#  block7d_se_excite (Multipl  (None, 5, 5, 3840)           0         ['block7d_activation[0][0]',
#  y)                                                                  'block7d_se_expand[0][0]']
#
#  block7d_project_conv (Conv  (None, 5, 5, 640)            2457600   ['block7d_se_excite[0][0]']
#  2D)
#
#  block7d_project_bn (BatchN  (None, 5, 5, 640)            2560      ['block7d_project_conv[0][0]']
#  ormalization)
#
#  block7d_drop (Dropout)      (None, 5, 5, 640)            0         ['block7d_project_bn[0][0]']
#
#  block7d_add (Add)           (None, 5, 5, 640)            0         ['block7d_drop[0][0]',
#                                                                      'block7c_add[0][0]']
#
#  top_conv (Conv2D)           (None, 5, 5, 2560)           1638400   ['block7d_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 5, 5, 2560)           10240     ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 5, 5, 2560)           0         ['top_bn[0][0]']
#  )
#
#  global_average_pooling2d (  (None, 2560)                 0         ['top_activation[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2560)                 0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 4)                    10244     ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 64107931 (244.55 MB)
# Trainable params: 63797204 (243.37 MB)
# Non-trainable params: 310727 (1.19 MB)
# __________________________________________________________________________________________________

# %%
history = model.fit(X_train,y_train,validation_split=0.1, epochs =12, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/12
# 85/85 [==============================] - ETA: 0s - loss: 1.1660 - accuracy: 0.5375
# Epoch 1: val_accuracy did not improve from 0.83667
# 85/85 [==============================] - 210s 857ms/step - loss: 1.1660 - accuracy: 0.5375 - val_loss: 0.5923 - val_accuracy: 0.7800 - lr: 1.0000e-05
# Epoch 2/12
# 85/85 [==============================] - ETA: 0s - loss: 0.7393 - accuracy: 0.7084
# Epoch 2: val_accuracy did not improve from 0.83667
# 85/85 [==============================] - 69s 816ms/step - loss: 0.7393 - accuracy: 0.7084 - val_loss: 0.6093 - val_accuracy: 0.7700 - lr: 1.0000e-05
# Epoch 3/12
# 85/85 [==============================] - ETA: 0s - loss: 0.5384 - accuracy: 0.8020
# Epoch 3: val_accuracy did not improve from 0.83667
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 2.9999999242136253e-06.
# 85/85 [==============================] - 70s 819ms/step - loss: 0.5384 - accuracy: 0.8020 - val_loss: 0.5893 - val_accuracy: 0.7800 - lr: 1.0000e-05
# Epoch 4/12
# 85/85 [==============================] - ETA: 0s - loss: 0.4485 - accuracy: 0.8317
# Epoch 4: val_accuracy did not improve from 0.83667
# 85/85 [==============================] - 70s 820ms/step - loss: 0.4485 - accuracy: 0.8317 - val_loss: 0.6191 - val_accuracy: 0.7633 - lr: 3.0000e-06
# Epoch 5/12
# 85/85 [==============================] - ETA: 0s - loss: 0.3980 - accuracy: 0.8492
# Epoch 5: val_accuracy did not improve from 0.83667
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 8.999999636216671e-07.
# 85/85 [==============================] - 70s 829ms/step - loss: 0.3980 - accuracy: 0.8492 - val_loss: 0.6227 - val_accuracy: 0.7500 - lr: 3.0000e-06
# Epoch 6/12
# 85/85 [==============================] - ETA: 0s - loss: 0.3629 - accuracy: 0.8681
# Epoch 6: val_accuracy did not improve from 0.83667
# 85/85 [==============================] - 70s 821ms/step - loss: 0.3629 - accuracy: 0.8681 - val_loss: 0.5916 - val_accuracy: 0.7767 - lr: 9.0000e-07
# Epoch 7/12
# 85/85 [==============================] - ETA: 0s - loss: 0.3758 - accuracy: 0.8663
# Epoch 7: val_accuracy did not improve from 0.83667
# 85/85 [==============================] - 70s 823ms/step - loss: 0.3758 - accuracy: 0.8663 - val_loss: 0.5282 - val_accuracy: 0.8000 - lr: 9.0000e-07
# Epoch 8/12
# 85/85 [==============================] - ETA: 0s - loss: 0.3710 - accuracy: 0.8726
# Epoch 8: val_accuracy improved from 0.83667 to 0.84667, saving model to effnet.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 85/85 [==============================] - 75s 878ms/step - loss: 0.3710 - accuracy: 0.8726 - val_loss: 0.4483 - val_accuracy: 0.8467 - lr: 9.0000e-07
# Epoch 9/12
# 85/85 [==============================] - ETA: 0s - loss: 0.3517 - accuracy: 0.8737
# Epoch 9: val_accuracy improved from 0.84667 to 0.85667, saving model to effnet.h5
# 85/85 [==============================] - 76s 900ms/step - loss: 0.3517 - accuracy: 0.8737 - val_loss: 0.4137 - val_accuracy: 0.8567 - lr: 9.0000e-07
# Epoch 10/12
# 85/85 [==============================] - ETA: 0s - loss: 0.3407 - accuracy: 0.8782
# Epoch 10: val_accuracy improved from 0.85667 to 0.87667, saving model to effnet.h5
# 85/85 [==============================] - 76s 899ms/step - loss: 0.3407 - accuracy: 0.8782 - val_loss: 0.3929 - val_accuracy: 0.8767 - lr: 9.0000e-07
# Epoch 11/12
# 85/85 [==============================] - ETA: 0s - loss: 0.3327 - accuracy: 0.8852
# Epoch 11: val_accuracy improved from 0.87667 to 0.88333, saving model to effnet.h5
# 85/85 [==============================] - 76s 889ms/step - loss: 0.3327 - accuracy: 0.8852 - val_loss: 0.3815 - val_accuracy: 0.8833 - lr: 9.0000e-07
# Epoch 12/12
# 85/85 [==============================] - ETA: 0s - loss: 0.3307 - accuracy: 0.8845
# Epoch 12: val_accuracy improved from 0.88333 to 0.88667, saving model to effnet.h5
# 85/85 [==============================] - 76s 893ms/step - loss: 0.3307 - accuracy: 0.8845 - val_loss: 0.3739 - val_accuracy: 0.8867 - lr: 9.0000e-07

# %%
filterwarnings('ignore')

epochs = [i for i in range(12)]
fig, ax = plt.subplots(1,2,figsize=(14,7))
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

fig.text(s='Epochs vs. Training and Validation Accuracy/Loss',size=18,fontweight='bold',
             fontname='monospace',color=colors_dark[1],y=1,x=0.28,alpha=0.8)

sns.despine()
ax[0].plot(epochs, train_acc, marker='o',markerfacecolor=colors_green[2],color=colors_green[3],
           label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, marker='o',markerfacecolor=colors_red[2],color=colors_red[3],
           label = 'Validation Accuracy')
ax[0].legend(frameon=False)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')

sns.despine()
ax[1].plot(epochs, train_loss, marker='o',markerfacecolor=colors_green[2],color=colors_green[3],
           label ='Training Loss')
ax[1].plot(epochs, val_loss, marker='o',markerfacecolor=colors_red[2],color=colors_red[3],
           label = 'Validation Loss')
ax[1].legend(frameon=False)
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Training & Validation Loss')

fig.show()

# %% [markdown]
# ### **Prediction**

# %% [markdown]
# I've used the *argmax* function as each row from the prediction array contains four values for the respective labels. The **maximum** value which is in each row depicts the predicted output out of the 4 possible outcomes.
# So with argmax, I'm able to find out the index associated with the predicted outcome.

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 11/11 [==============================] - 9s 325ms/step

# %% [markdown]
# ### **Evoluation**

# %% [markdown]
# In this,
#
# *   0 - Glioma Tumor
# *   1 - No Tumor
#
# *   2 - Meningioma Tumor
# *   3 - Pituitary Tumor

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.82      0.88       105
#            1       0.91      0.91      0.91        47
#            2       0.79      0.85      0.81        91
#            3       0.88      0.96      0.91        90
#
#     accuracy                           0.88       333
#    macro avg       0.88      0.88      0.88       333
# weighted avg       0.88      0.88      0.88       333

# %%
fig,ax=plt.subplots(1,1,figsize=(14,7))
sns.heatmap(confusion_matrix(y_test_new,pred),ax=ax,xticklabels=labels,yticklabels=labels,annot=True,
           cmap=colors_green[::-1],alpha=0.7,linewidths=2,linecolor=colors_dark[3])
fig.text(s='Heatmap of the Confusion Matrix',size=18,fontweight='bold',
             fontname='monospace',color=colors_dark[1],y=0.92,x=0.28,alpha=0.8)

plt.show()
